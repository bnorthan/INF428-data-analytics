# %%
import pandas as pd

# %%
nba=pd.read_csv('../../data/Dahlin/per36min.csv',parse_dates=True, index_col=0)
print nba.shape
print nba

# %%
nba.describe()
# Out:
#               Age           G          GS           MP          FG  \
# count  651.000000  651.000000  651.000000   651.000000  651.000000
# mean    26.500768   45.960061   21.099846  1041.775730    5.035791
# std      4.110914   25.503151   25.932412   806.253103    1.812824
# min     19.000000    1.000000    0.000000     1.000000    0.000000
# 25%     23.000000   24.000000    0.000000   272.000000    4.000000
# 50%     26.000000   48.000000    9.000000   896.000000    4.900000
# 75%     29.000000   70.000000   35.000000  1674.000000    6.100000
# max     38.000000   83.000000   82.000000  2981.000000   18.000000
#
#               FGA         FG%          3P         3PA         3P%     ...      \
# count  651.000000  649.000000  651.000000  651.000000  570.000000     ...
# mean    11.886329    0.427404    1.089094    3.405376    0.286454     ...
# std      3.540223    0.100285    1.005854    2.794806    0.137568     ...
# ...

# %%
defensive = nba [['Tm','TRB','AST','STL','BLK']]
defensive.head()
# Out:
#      Tm   TRB  AST  STL  BLK
# Rk
# 1   NYK   8.4  1.9  0.8  0.6
# 2   MEM   4.1  2.3  2.3  1.0
# 3   OKC  10.6  1.3  0.8  1.7
# 4   MIN  12.9  2.5  0.7  1.5
# 5   TOT   3.6  1.9  0.6  0.1

# %%
defensive=nba.groupby('Tm')
print type(defensive)
print len(defensive)
by_Def=defensive.mean()
print type(by_Def)
print
print by_Def.head()
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>
# 31
# <class 'pandas.core.frame.DataFrame'>
#
#            Age          G         GS           MP        FG        FGA  \
# Tm
# ATL  27.000000  54.250000  25.625000  1233.250000  5.243750  11.856250
# BOS  26.181818  39.863636  18.636364   903.636364  5.850000  12.931818
# BRK  27.526316  46.842105  21.578947  1048.842105  4.921053  11.552632
# CHI  28.285714  58.642857  29.285714  1420.071429  4.892857  11.521429
# CHO  26.117647  49.941176  24.117647  1170.882353  5.258824  12.676471
#
#           FG%        3P       3PA       3P%    ...           FT%       ORB  \
# Tm                                             ...
# ATL  0.442937  1.393750  3.943750  0.316125    ...      0.733625  1.450000
# BOS  0.444727  1.209091  3.727273  0.316737    ...      0.695773  1.686364
# BRK  0.413737  0.805263  2.710526  0.241588    ...      0.710368  1.663158
# CHI  0.419000  1.085714  3.114286  0.327727    ...      0.722214  1.742857
# ...

# %%
print nba.columns
nba=nba[['Tm','TRB','AST','STL','BLK']]
print nba
# Out:
# Index([u'Player', u'Pos', u'Age', u'Tm', u'G', u'GS', u'MP', u'FG', u'FGA',
#        u'FG%', u'3P', u'3PA', u'3P%', u'2P', u'2PA', u'2P%', u'FT', u'FTA',
#        u'FT%', u'ORB', u'DRB', u'TRB', u'AST', u'STL', u'BLK', u'TOV', u'PF',
#        u'PTS'],
#       dtype='object')
#       Tm   TRB  AST  STL  BLK
# Rk
# 1    NYK   8.4  1.9  0.8  0.6
# 2    MEM   4.1  2.3  2.3  1.0
# 3    OKC  10.6  1.3  0.8  1.7
# 4    MIN  12.9  2.5  0.7  1.5
# 5    TOT   3.6  1.9  0.6  0.1
# 5    DEN   3.7  2.1  0.7  0.1
# 5    POR   3.2  1.3  0.4  0.1
# 6    NOP  11.8  1.8  0.8  1.9
# 7    PHI  11.7  1.9  1.1  1.1
# 8    NYK  12.5  2.8  1.4  2.4
# 9    POR  10.4  1.8  0.7  1.0
# 10   IND  10.9  2.5  0.5  1.4
# 11   MEM   6.1  1.9  2.8  0.7
# 12   DAL   9.0  1.6  1.8  1.6
# 13   TOT  10.3  2.7  0.8  2.0
# 13   CLE   9.1  2.3  0.5  0.0
# 13   NYK  10.4  2.7  0.9  2.2
# 14   MIA   9.5  1.4  0.8  1.9
# 15   BRK   4.2  1.7  1.2  0.1
# 16   SAS   7.2  2.8  1.5  0.7
# 17   NOP   6.3  1.2  0.7  0.4
# ...

# %%
my_plot = defensive.plot.bar()
defensive2=defensive.set_index('Tm')
defensive2.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-4abee513fbad> in <module>()
#       1 my_plot = defensive.plot.bar()
# ----> 2 defensive2=defensive.set_index('Tm')
#       3 defensive2.head()
#
# C:\Users\Dahlin\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in __getattr__(self, attr)
#     554             return self[attr]
#     555         if hasattr(self.obj, attr):
# --> 556             return self._make_wrapper(attr)
#     557
#     558         raise AttributeError("%r object has no attribute %r" %
#
# C:\Users\Dahlin\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in _make_wrapper(self, name)
#     571                    "using the 'apply' method".format(kind, name,
#     572                                                      type(self).__name__))
# --> 573             raise AttributeError(msg)
#     574
# ...
