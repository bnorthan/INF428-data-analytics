# %%
import pandas as pd

# %%
nba=pd.read_csv('../../data/Dahlin/per36min.csv',parse_dates=True, index_col=0)
print nba.shape
print nba
# Out:
# (651, 28)
#                     Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  \
# Rk
# 1               Quincy Acy  PF   24  NYK  68  22  1287  4.3   9.3  0.459
# 2             Jordan Adams  SG   20  MEM  30   0   248  5.1  12.5  0.407
# 3             Steven Adams   C   21  OKC  70  67  1771  4.4   8.1  0.544
# 4              Jeff Adrien  PF   28  MIN  17   0   215  3.2   7.4  0.432
# 5            Arron Afflalo  SG   29  TOT  78  72  2502  5.4  12.7  0.424
# 5            Arron Afflalo  SG   29  DEN  53  53  1750  5.8  13.5  0.428
# 5            Arron Afflalo  SG   29  POR  25  19   752  4.5  10.9  0.414
# 6            Alexis Ajinca   C   26  NOP  68   8   957  6.8  12.4  0.550
# 7           Furkan Aldemir  PF   23  PHI  41   9   540  2.7   5.2  0.513
# 8             Cole Aldrich   C   26  NYK  61  16   976  5.3  11.1  0.478
# 9        LaMarcus Aldridge  PF   29  POR  71  71  2512  9.4  20.3  0.466
# 10             Lavoy Allen  PF   25  IND  63   0  1070  4.7  10.1  0.472
# ...

# %%
nba.describe()
# Out:
#               Age           G          GS           MP          FG  \
# count  651.000000  651.000000  651.000000   651.000000  651.000000
# mean    26.500768   45.960061   21.099846  1041.775730    5.035791
# std      4.110914   25.503151   25.932412   806.253103    1.812824
# min     19.000000    1.000000    0.000000     1.000000    0.000000
# 25%     23.000000   24.000000    0.000000   272.000000    4.000000
# 50%     26.000000   48.000000    9.000000   896.000000    4.900000
# 75%     29.000000   70.000000   35.000000  1674.000000    6.100000
# max     38.000000   83.000000   82.000000  2981.000000   18.000000
#
#               FGA         FG%          3P         3PA         3P%     ...      \
# count  651.000000  649.000000  651.000000  651.000000  570.000000     ...
# mean    11.886329    0.427404    1.089094    3.405376    0.286454     ...
# std      3.540223    0.100285    1.005854    2.794806    0.137568     ...
# ...

# %%
defensive = nba [['Tm','TRB','STL','BLK']]
defensive.head()
# Out:
#      Tm   TRB  STL  BLK
# Rk
# 1   NYK   8.4  0.8  0.6
# 2   MEM   4.1  2.3  1.0
# 3   OKC  10.6  0.8  1.7
# 4   MIN  12.9  0.7  1.5
# 5   TOT   3.6  0.6  0.1

# %%
print nba.columns
nba=nba[['Tm','TRB','STL','BLK']]
print nba
defensive=nba.groupby('Tm')
print type(defensive)
print len(defensive)
by_Def=defensive.mean()
print type(by_Def)
print
print by_Def.head()
# Out:
# Index([u'Tm', u'TRB', u'AST', u'STL', u'BLK'], dtype='object')
#       Tm   TRB  STL  BLK
# Rk
# 1    NYK   8.4  0.8  0.6
# 2    MEM   4.1  2.3  1.0
# 3    OKC  10.6  0.8  1.7
# 4    MIN  12.9  0.7  1.5
# 5    TOT   3.6  0.6  0.1
# 5    DEN   3.7  0.7  0.1
# 5    POR   3.2  0.4  0.1
# 6    NOP  11.8  0.8  1.9
# 7    PHI  11.7  1.1  1.1
# 8    NYK  12.5  1.4  2.4
# 9    POR  10.4  0.7  1.0
# 10   IND  10.9  0.5  1.4
# 11   MEM   6.1  2.8  0.7
# 12   DAL   9.0  1.8  1.6
# 13   TOT  10.3  0.8  2.0
# 13   CLE   9.1  0.5  0.0
# 13   NYK  10.4  0.9  2.2
# 14   MIA   9.5  0.8  1.9
# 15   BRK   4.2  1.2  0.1
# 16   SAS   7.2  1.5  0.7
# 17   NOP   6.3  0.7  0.4
# 18   MIL   7.7  1.0  1.2
# 19   NYK   6.7  1.0  0.4
# 20   DET   8.2  1.1  4.3
# 21   ATL   6.6  0.6  0.5
# 22   HOU   5.6  1.9  0.2
# 23   DEN   6.2  1.7  0.9
# 24   NOP  13.6  0.5  1.0
# 25   TOT   3.0  0.9  0.1
# 25   DET   2.8  0.9  0.1
# ..   ...   ...  ...  ...
# 476  SAC   5.0  0.8  0.1
# 477  TOT   2.4  1.2  0.0
# ...

# %%
# %matplotlib inline
nba.plot(kind='bar')('Tm','TRB','STL','BLK')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-a8e87a0034f4> in <module>()
#       1 get_ipython().magic(u'matplotlib inline')
# ----> 2 nba.plot(kind='bar')('Tm','TRB','STL','BLK')
#
# TypeError: 'AxesSubplot' object is not callable

# %%
my_plot = nba.plot.bar()
defensive=nba.set_index('Tm')
defensive=nba.iloc[0:50]
nba.plot.bar(stacked=True)
