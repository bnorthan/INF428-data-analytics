# %%
# run pip install feedparser
import feedparser as fp

# %%
rss=fp.parse("http://mlb.mlb.com/partnerxml/gen/news/rss/tor.xml")

# %%
print "num entries",len(rss.entries)
# Out:
# num entries 22

# %%
print type(rss.entries)
# Out:
# <type 'list'>

# %%
for entry in rss.entries:
    print type(entry)
    
    print entry['content']
    print
# Out:
# <class 'feedparser.FeedParserDict'>
# [{'base': u'http://mlb.mlb.com/partnerxml/gen/news/rss/tor.xml', 'type': u'text/html', 'value': u"The ideal situation for any new hire is to receive at least a few days to settle into a job, but Ross Atkins doesn't have that luxury. Instead, he's about to be tossed into the center of Major League Baseball's biggest offseason event.", 'language': None}]
#
# <class 'feedparser.FeedParserDict'>
# [{'base': u'http://mlb.mlb.com/partnerxml/gen/news/rss/tor.xml', 'type': u'text/html', 'value': u'The Blue Jays on Friday signed catcher Josh Thole to a one-year, $800,000 contract. Thole, who appeared in 18 games last season for Toronto, will contend for the backup position behind starting catcher Russell Martin.', 'language': None}]
#
# <class 'feedparser.FeedParserDict'>
# ...

# %%
from bs4 import BeautifulSoup
import re
import urllib2 as url

# %%
response=url.urlopen('http://www.hmrrc.com/View/PDFs/Results/troytthis.htm')

soup = BeautifulSoup(response)

# %%
table1=soup.table

for row in table1:
    for col in row:
        print type(col)
# Out:
# <type 'unicode'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <type 'unicode'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <type 'unicode'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>
# ...
