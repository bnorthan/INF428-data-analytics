# %%
import pandas as pd

# %%
datingData=pd.read_csv('../../data/MachineLearning/datingTestSet.txt', '\t')
datingData.columns=['frequent_fliers', 'time_gaming', 'litres_icecream', 'did_she_like']

# %%
print datingData.shape
datingData.head()
# Out:
# (1000, 4)
#    frequent_fliers  time_gaming  litres_icecream did_she_like
# 0            40920     8.326976         0.953952   largeDoses
# 1            14488     7.153469         1.673904   smallDoses
# 2            26052     1.441871         0.805124    didntLike
# 3            75136    13.147394         0.428964    didntLike
# 4            38344     1.669788         0.134296    didntLike

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ld=datingData[datingData.did_she_like=='largeDoses']
sd=datingData[datingData.did_she_like=='smallDoses']
dl=datingData[datingData.did_she_like=='didntLike']

# %%
training=datingData.iloc[0:250]
testing=datingData.iloc[250:]

xtrain=training[['frequent_fliers','time_gaming','litres_icecream']].values
xtest=testing[['frequent_fliers','time_gaming','litres_icecream']].values
ytrain=training['did_she_like'].map(lambda x:if x=='largeDose')

# %%
plt.figure(figsize=(20,10))

plt.scatter(ld['frequent_fliers'], ld['time_gaming'], color='r')
plt.scatter(sd['frequent_fliers'], sd['time_gaming'], color='g')
plt.scatter(dl['frequent_fliers'], dl['time_gaming'], color='b')
# Out:
# /home/bnorthan/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
from sklearn.narive_bayes import GaussianNB
gnb=GaussianNB()
model=gnb.fit()
