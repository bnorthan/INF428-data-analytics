# %%
import matplotlib.pyplot as plt

# %matplotlib inline
numbers1=[1,2, 3]
numbers2=[1, 2, 3]
numbers3=[5000, 3000, 1000]

plt.scatter(numbers1, numbers2)

# %%
plt.scatter(numbers1, numbers2, s=numbers3, marker='o', c=numbers3)
