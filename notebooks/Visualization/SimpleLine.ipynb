# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x=[1,2,3,4,5]
y=[10, 20, 10, 30, 40]

# %%
type(plt)
# Out:
# module

# %%
plt.plot(x,y)
plt.show()

# %%
import numpy as np

x=np.linspace(0,20)
plt.plot(x, 0.5+x)
plt.plot(x, 10+2*x, '--')

plt.show()
