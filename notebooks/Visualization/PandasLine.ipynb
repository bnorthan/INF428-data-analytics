# %%
# %matplotlib inline
import pandas as pd

# %%
msft=pd.read_csv('../../data/economics/microsoft.csv')
type(msft)
print msft.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-534c56852ddc> in <module>()
# ----> 1 msft=pd.read_csv('../../data/economics/microsoft.csv')
#       2 type(msft)
#       3 print msft.head()
#
# NameError: name 'pd' is not defined

# %%
msft.Close.plot()

# %%
msft.head()
msft=msft.sort('Date')
# Out:
# C:\Users\bnorthan\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#             Date  Open  High  Low  Close    Volume
# 7311  1986-03-13     0   NaN  NaN    0.1  30758400
# 7310  1986-03-14     0   NaN  NaN    0.1   7852896
# 7309  1986-03-17     0   NaN  NaN    0.1  33036768
# 7308  1986-03-18     0   NaN  NaN    0.1  66403296
# 7307  1986-03-19     0   NaN  NaN    0.1  47846304

# %%
msft.Close.plot()

# %%
gv=pd.read_csv('../../data/crime/gunviolence.csv', index_col=0)
gv
# Out:
#       White  Black  American_Indian  Asian  Rate_White  Rate_Black  \
# Year
# 1993   7918   9824              106    405         3.7        30.1
# 1994   7774   9302              123    328         3.6        28.0
# 1995   7144   7935              130    342         3.2        23.4
# 1996   6240   7403               90    304         2.8        21.5
# 1997   6025   6841               96    290         2.7        19.5
# 1998   5412   6053               99    234         2.4        17.0
# 1999   4918   5577              104    229         2.2        15.4
# 2000   4806   5699               86    210         2.1        15.6
# 2001   5188   5885               87    188         2.2        15.8
# 2002   5185   6285              117    242         2.2        16.7
# 2003   5173   6397              109    241         2.2        16.7
# 2004   5119   6201              104    200         2.2        16.0
# 2005   5266   6703              117    266         2.2        17.1
# ...

# %%
print gv.columns
gv=gv[['Rate_White',' Rate_Asian']]
print gv.head()
# Out:
# Index([u'White', u'Black', u'American_Indian', u'Asian', u'Rate_White',
#        u'Rate_Black', u'Rate_American_Indian', u' Rate_Asian'],
#       dtype='object')
#       Rate_White   Rate_Asian
# Year
# 1993         3.7          4.6
# 1994         3.6          3.6
# 1995         3.2          3.6
# 1996         2.8          3.0
# 1997         2.7          2.8

# %%
gv.plot(figsize=(10,10))

# %%
# %matplotlib inline
gv.plot(figsize=(10,10), stacked=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-c6414e3638c6> in <module>()
# ----> 1 gv.pivot_table()
#
# C:\Users\bnorthan\Anaconda2\lib\site-packages\pandas\tools\pivot.pyc in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     111             data = data[to_filter]
#     112
# --> 113     grouped = data.groupby(keys)
#     114     agged = grouped.agg(aggfunc)
#     115
#
# C:\Users\bnorthan\Anaconda2\lib\site-packages\pandas\core\generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze)
#    3434         axis = self._get_axis_number(axis)
#    3435         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
# -> 3436                        sort=sort, group_keys=group_keys, squeeze=squeeze)
#    3437
# ...
